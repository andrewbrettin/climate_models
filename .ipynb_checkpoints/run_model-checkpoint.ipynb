# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

from energy_balance_model import EnergyBalanceModel
from numpy import fft
from scipy.integrate import solve_ivp
from scipy.constants import sigma

# %%
model = EnergyBalanceModel()

model.run_model()
# Out:
# /Users/andrewbrettin/Desktop/Class/climate_change/climate_models/energy_balance_model.py:89: UserWarning: Unstable timestep for diffusion term.
#   warnings.warn('Unstable timestep for diffusion term.')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-efef4b787fa4> in <module>
#       1 model = EnergyBalanceModel()
#       2
# ----> 3 model.run_model()
#
# ~/Desktop/Class/climate_change/climate_models/energy_balance_model.py in run_model(self, res, dt, N, T_0, method)
#     108
#     109             ode_sol = solve_ivp(F, (ts[n], ts[n+1]), np.array(T_last), method=method, t_eval=(ts[n], ts[n+1]))
# --> 110             T_ode = ode_sol.y[:,1]
#     111
#     112
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
np.shape(model.T_grid)
# Out:
# (100, 19)

# %%
fig, ax = plt.subplots()
model.show_animation()
